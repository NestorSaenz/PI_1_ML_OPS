# %%
import pandas as pd
import gzip
import ast
import pyarrow as pa
import pyarrow.parquet as pq

# %% [markdown]
# ## Ingesta de datos (Extracion)

# %%
# Ruta del archivo JSON
file_path = 'Dataset/user_reviews.json.gz'
data = []

# Abrir el archivo y procesar cada línea
with gzip.open(file_path, 'rt', encoding='utf-8') as file:
    for line in file:
        try:
            # Usar ast.literal_eval para convertir la línea en un diccionario
            json_data = ast.literal_eval(line)
            data.append(json_data)
        except ValueError as e:
            print(f"Error en la línea: {line}")
            continue

#Crear un DataFrame a partir de la lista de diccionarios
df_original = pd.DataFrame(data)
df_original.head(3)
# Out:
#              user_id                                           user_url  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1            js41637               http://steamcommunity.com/id/js41637
# 2          evcentric             http://steamcommunity.com/id/evcentric
#
#                                              reviews
# 0  [{'funny': '', 'posted': 'Posted November 5, 2...
# 1  [{'funny': '', 'posted': 'Posted June 24, 2014...
# 2  [{'funny': '', 'posted': 'Posted February 3.',...

# %% [markdown]
# ## Transformacion de los datos
# Desanido la columna que necesito 'reviews'

# %%
df_review = df_original.explode('reviews') #con la funcion explode() se desglosa las listas de diccionarios en filas individuales
df_review = pd.concat([df_review.drop(['reviews'],axis= 1), df_review['reviews'].apply(pd.Series)], axis = 1) # concatena para que cada item del diccionario quede en columnas individuales.
df_review.rename(columns= {0: 'sentiment_analysis'}, inplace= True)
df_review.drop(['funny', 'posted', 'last_edited', 'helpful'], axis=1, inplace=True), # se borra las columnas que se prevee no son necesarias
df_review['sentiment_analysis'] = 0
df_review.head(3)
# Out:
#              user_id                                           user_url  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
#
#   item_id recommend                                             review  \
# 0    1250      True  Simple yet with great replayability. In my opi...
# 0   22200      True               It's unique and worth a playthrough.
# 0   43110      True  Great atmosphere. The gunplay can be a bit chu...
#
#    sentiment_analysis
# 0                   0
# 0                   0
# 0                   0

# %% [markdown]
# Revision de valores nulos para 'item_id'

# %%
df_review['item_id'].isna().value_counts() # se cuentan cuantos valores nulo existen
# Out:
# item_id
# False    59305
# True        28
# Name: count, dtype: int64

# %% [markdown]
# Se eliminan los valores nulos de la columna 'item_id'

# %%
df_review = df_review.dropna(subset= ['item_id'])
df_review.shape
# Out:
# (59305, 6)

# %% [markdown]
# ## Analisis de sentimientos

# %%
# Para resolver este punto se importan las librerias necesarias
from textblob import TextBlob

# %%
# Función para asignar el valor de sentimiento
def analisis_sentimiento(review:str) -> int:
  
    if not review:
        return 1  # Valor neutro si no hay texto
    else:
        analisis = TextBlob(review)
        if analisis.sentiment.polarity < 0:
            return 0  # Valor 0 para sentimiento negativo (malo)
        elif analisis.sentiment.polarity == 0:
            return 1  # Valor 1 para sentimiento neutro
        else:
            return 2  # Valor 2 para sentimiento positivo (bueno)

# %%
df_review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 59305 entries, 0 to 25798
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   user_id             59305 non-null  object
#  1   user_url            59305 non-null  object
#  2   item_id             59305 non-null  object
#  3   recommend           59305 non-null  object
#  4   review              59305 non-null  object
#  5   sentiment_analysis  59305 non-null  int64
# dtypes: int64(1), object(5)
# memory usage: 3.2+ MB

# %%
df_review['sentiment_analysis'] = df_review['review'].apply(analisis_sentimiento)
df_review
# Out:
#                  user_id                                           user_url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1                js41637               http://steamcommunity.com/id/js41637
# 1                js41637               http://steamcommunity.com/id/js41637
# ...                  ...                                                ...
# 25797  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 25797  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 25798        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
# 25798        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
# 25798        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
#
#       item_id recommend                                             review  \
# 0        1250      True  Simple yet with great replayability. In my opi...
# 0       22200      True               It's unique and worth a playthrough.
# 0       43110      True  Great atmosphere. The gunplay can be a bit chu...
# 1      251610      True  I know what you think when you see this title ...
# 1      227300      True  For a simple (it's actually not all that simpl...
# ...       ...       ...                                                ...
# 25797      70      True  a must have classic from steam definitely wort...
# 25797  362890      True  this game is a perfect remake of the original ...
# 25798  273110      True  had so much fun plaing this and collecting res...
# 25798     730      True                                                 :D
# 25798     440      True                                     so much fun :D
#
#        sentiment_analysis
# 0                       2
# 0                       2
# 0                       2
# 1                       2
# 1                       0
# ...                   ...
# 25797                   2
# 25797                   2
# 25798                   2
# 25798                   2
# 25798                   2
#
# [59305 rows x 6 columns]

# %%
df_review[df_review['sentiment_analysis'] == 1].sample(20)
# Out:
#                  user_id                                           user_url  \
# 10091  76561198091404694  http://steamcommunity.com/profiles/76561198091...
# 21642       DerpingKoala          http://steamcommunity.com/id/DerpingKoala
# 20943  76561198058784699  http://steamcommunity.com/profiles/76561198058...
# 3894   76561198039506014  http://steamcommunity.com/profiles/76561198039...
# 13233    inconsequential       http://steamcommunity.com/id/inconsequential
# 9438   76561198085294887  http://steamcommunity.com/profiles/76561198085...
# 11313      TheWatchdogEM         http://steamcommunity.com/id/TheWatchdogEM
# 8139             Ryan264               http://steamcommunity.com/id/Ryan264
# 7587              Breadi                http://steamcommunity.com/id/Breadi
# 5171   76561198064394417  http://steamcommunity.com/profiles/76561198064...
# 12876           IgniteAU              http://steamcommunity.com/id/IgniteAU
# 24831          LeoNoHomo             http://steamcommunity.com/id/LeoNoHomo
# 12692            bzr9000               http://steamcommunity.com/id/bzr9000
# 4853   76561198067309171  http://steamcommunity.com/profiles/76561198067...
# 21318        PizzaManKAK           http://steamcommunity.com/id/PizzaManKAK
# 21285        Plasmahippo           http://steamcommunity.com/id/Plasmahippo
# 8885          ghost-loli            http://steamcommunity.com/id/ghost-loli
# 21507         The_Goosey            http://steamcommunity.com/id/The_Goosey
# 19844          Gotcharrr             http://steamcommunity.com/id/Gotcharrr
# 14875              NKraz                 http://steamcommunity.com/id/NKraz
#
#       item_id recommend                                             review  \
# 10091  252490      True  Ran around naked with a terrorist mask on.Shou...
# 21642  224260      True                                       This is funy
# 20943     400      True                                       I like cake!
# 3894   233250     False                                                No.
# 13233  285900      True  This is basically what jelly babys do when you...
# 9438      730      True                                         Otimo jogo
# 11313  317360      True                       Can I Have My 5 Minutes Back
# 8139   286160      True            ♥♥♥♥ MY CARDDDDDDDDDDDDDS (flips table)
# 7587      440      True     Adoro esse jogo. Jogo o dia todo, melhor jogo.
# 5171    17390      True                                I made a human10/10
# 12876  311210      True  Treyarch ✔Dedicated Servers ✔Great Zombies ✔Gr...
# 24831  219870      True               hahahahahahahahhahahahahahahahahahah
# 12692  221910      True  Seus atos influenciam de verdade no seu futuro...
# 4853   242760      True    I put a head on a stick and lit it on fire10/10
# 21318  295110      True                                 สนุกดี ฮาด้วย 9/10
# 21285  275850     False                                           its ♥♥♥♥
# 8885      550      True                                ของฟรีนี่มันดีจริงๆ
# 21507  265930      True                                              Goats
# 19844  224600      True                                                 uh
# 14875    4000      True                                      It's Garry's.
#
#        sentiment_analysis
# 10091                   1
# 21642                   1
# 20943                   1
# 3894                    1
# 13233                   1
# 9438                    1
# 11313                   1
# 8139                    1
# 7587                    1
# 5171                    1
# 12876                   1
# 24831                   1
# 12692                   1
# 4853                    1
# 21318                   1
# 21285                   1
# 8885                    1
# 21507                   1
# 19844                   1
# 14875                   1

# %%
df_review[df_review['user_id'] == 'zyr0n1c']
# Out:
#        user_id                              user_url item_id recommend  \
# 24058  zyr0n1c  http://steamcommunity.com/id/zyr0n1c     620      True
# 24058  zyr0n1c  http://steamcommunity.com/id/zyr0n1c  230410      True
# 24058  zyr0n1c  http://steamcommunity.com/id/zyr0n1c   72850      True
# 24058  zyr0n1c  http://steamcommunity.com/id/zyr0n1c     730      True
# 24058  zyr0n1c  http://steamcommunity.com/id/zyr0n1c  208090      True
# 24058  zyr0n1c  http://steamcommunity.com/id/zyr0n1c   17470      True
# 24058  zyr0n1c  http://steamcommunity.com/id/zyr0n1c    4000      True
# 24058  zyr0n1c  http://steamcommunity.com/id/zyr0n1c     440      True
# 24058  zyr0n1c  http://steamcommunity.com/id/zyr0n1c    8980      True
#
#                                                   review  sentiment_analysis
# 24058  Fantastic Game! It allows one to think really ...                   0
# 24058  Fantastic game! Lots of gamemodes and large va...                   2
# 24058  It's been a long way since Elder Scrolls start...                   2
# 24058  After playing 500 hours on this fantastic FPS,...                   0
# 24058                       Great game. Good physics l0l                   2
# 24058            Dis game is action packed and thrilling                   0
# 24058  Great Game! With lots and lots of props to pla...                   2
# 24058  THis FPS Shooter game really packs a punch.I'm...                   0
# 24058  A Gem.It's level of stupidity is just overwhem...                   0

# %% [markdown]
# Ultimas transformaciones

# %%
df_review = df_review.drop(columns=['user_url', 'review'])

# %%
df_review
# Out:
#                  user_id item_id recommend  sentiment_analysis
# 0      76561197970982479    1250      True                   2
# 0      76561197970982479   22200      True                   2
# 0      76561197970982479   43110      True                   2
# 1                js41637  251610      True                   2
# 1                js41637  227300      True                   0
# ...                  ...     ...       ...                 ...
# 25797  76561198312638244      70      True                   2
# 25797  76561198312638244  362890      True                   2
# 25798        LydiaMorley  273110      True                   2
# 25798        LydiaMorley     730      True                   2
# 25798        LydiaMorley     440      True                   2
#
# [59305 rows x 4 columns]

# %% [markdown]
# Se exporta el dataset para u uso en la API

# %%
df_review.to_csv("Dataset/user_review.parquet")
